# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread('sc.png')
imgplot = plt.imshow(img)

# %% [markdown]
# ## Point Processing
# ‒ Point operators
#
# ‒ Histogram and histogram egalization

# %% [markdown]
# ## Arithmetic Operation

# %%
#Addition of Image:
img1 = cv2.imread('1.jpg')
img2 = cv2.imread('2.jpg')

# cv2.addWeighted is applied over the 
# image inputs with applied parameters 
weightedSum = cv2.addWeighted(img1, 0.5, img2, 0.4, 0) 
  
# the window showing output image 
# with the weighted sum  
# cv2.imshow('Weighted Image', weightedSum)

# if cv2.waitKey(0) & 0xff == 27:  
#     cv2.destroyAllWindows()

cv2.imwrite('add.jpg', weightedSum)
# Out:
# True

# %%
#Subtraction of Image:
sub = cv2.subtract(img1, img2)
cv2.imwrite('sub.jpg', sub)
# Out:
# True

# %% [markdown]
# ## Bitwise operation
# AND
# OR
# XOR
# NOT

# %%
#AND
dest_and = cv2.bitwise_and(img2, img1, mask = None)
cv2.imwrite('and.jpg', dest_and)
# Out:
# True

# %%
#OR
dest_or = cv2.bitwise_or(img2, img1, mask = None)
cv2.imwrite('or.jpg', dest_or)
# Out:
# True

# %%
#XOR
dest_xor = cv2.bitwise_xor(img1, img2, mask = None)
cv2.imwrite('xor.jpg', dest_xor)
# Out:
# True

# %%
#NOT
dest_not1 = cv2.bitwise_not(img1, mask = None) 
dest_not2 = cv2.bitwise_not(img2, mask = None) 

cv2.imwrite('not1.jpg', dest_not1) 
cv2.imwrite('not2.jpg', dest_not2)
# Out:
# True

# %% [markdown]
# # Image Preprocessing

# %% [markdown]
# ## 1. Image resizing
# Choice of Interpolation Method for Resizing –
#
# cv2.INTER_AREA: This is used when we need to shrink an image.
#
# cv2.INTER_CUBIC: This is slow but more efficient.
#
# cv2.INTER_LINEAR: This is primarily used when zooming is required. This is the default interpolation technique in OpenCV.

# %%
image = cv2.imread("oneD.jpg", 1)
# Loading the image
 
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (0,0),fx = 1.2, fy = 1.2)
 
stretch_near = cv2.resize(image, (780, 540), 
               interpolation = cv2.INTER_NEAREST)
 
 
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %% [markdown]
# ## 2. Erosion

# %%
image = cv2.imread("oneD.jpg", 1)

kernel1 = np.ones((5, 5), np.uint8)
kernel2 = np.ones((6, 6), np.uint8)
erosion1 = cv2.erode(image, kernel1)
erosion2 = cv2.erode(image, kernel, cv2.BORDER_REFLECT)
res = np.concatenate((erosion1, erosion2), axis = 1)
cv2.imwrite('erosion.jpg', res)
# Out:
# True

# %% [markdown]
# ## 3. Blurring
#
# #### Advantages of blurring:
#
# It helps in Noise removal. As noise is considered as high pass signal so by the application of low pass filter kernel we restrict noise.
#
# It helps in smoothing the image.
#
# Low intensity edges are removed.
#
# It helps in hiding the details when necessary. For e.g. in many cases police deliberately want to hide the face of the victim, in such cases blurring is required.
#
# #### type blurring
#  - Gaussian blur
#  - Median Blur
#  - Bilateral Blur

# %%
image = cv2.imread('oneD.jpg', 1)  
  
# Gaussian Blur 
Gaussian = cv2.GaussianBlur(image, (7, 7), 0) 
  
# Median Blur 
median = cv2.medianBlur(image, 5)   
  
# Bilateral Blur 
bilateral = cv2.bilateralFilter(image, 9, 75, 75) 

x1 = np.concatenate ((image, Gaussian), axis = 1)
x2 = np.concatenate ((median, bilateral), axis = 1)
x3 = np.concatenate ((x1, x2), axis = 0)

cv2.imwrite('blur.jpg', x3)
# Out:
# True

# %% [markdown]
# ## 4. Create Border
#  - cv2.BORDER_CONSTANT: It adds a constant colored border. The value should be given as next argument.
#  - cv2.BORDER_REFLECT: The border will be mirror reflection of the border elements. Suppose, if image contains letters “abcdefg” then output will be “gfedcba|abcdefg|gfedcba“.
#  - cv2.BORDER_REFLECT_101 or cv2.BORDER_DEFAULT: It does the same works as cv2.BORDER_REFLECT but with slight change. Suppose, if image contains letters “abcdefgh” then output will be “gfedcb|abcdefgh|gfedcba“.
#  - cv2.BORDER_REPLICATE: It replicates the last element. Suppose, if image contains letters “abcdefgh” then output will be “aaaaa|abcdefgh|hhhhh“.

# %%
image = cv2.imread('oneD.jpg') 
     
# Using cv2.copyMakeBorder() method 
constant = cv2.copyMakeBorder(image, 10, 10, 10, 10, cv2.BORDER_CONSTANT) 
reflect = cv2.copyMakeBorder(image, 10, 10, 10, 10, cv2.BORDER_REFLECT) 
replicate = cv2.copyMakeBorder(image, 10, 10, 10, 10, cv2.BORDER_REPLICATE) 
reflect_101 = cv2.copyMakeBorder(image, 10, 10, 10, 10, cv2.BORDER_REFLECT_101) 
      
# Writing the image
x1 = np.concatenate ((constant, reflect), axis = 1)
x2 = np.concatenate ((replicate, reflect_101), axis = 1)
x3 = np.concatenate ((x1, x2), axis = 0)
cv2.imwrite('border.jpg', x3)
# Out:
# True

# %% [markdown]
# ## 5. Grayscaling
# #### Importance of grayscaling –
#
# - Dimension reduction: For e.g. In RGB images there are three color channels and has three dimensions while grayscaled images are single dimensional.
# - Reduces model complexity: Consider training neural article on RGB images of 10x10x3 pixel.The input layer will have 300 input nodes. On the other hand, the same neural network will need only 100 input node for grayscaled images.
# - For other algorithms to work: There are many algorithms that are customized to work only on grayscaled images e.g. Canny edge detection function pre-implemented in OpenCV library works on Grayscaled images only.

# %%
# Load our input image 
image = cv2.imread('oneD.jpg') 
  
# We use cvtColor, to convert to grayscale 
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 

cv2.imwrite('grayScale.jpg', gray_image)
# Out:
# True

# %% [markdown]
# ## 6. Scaling, Rotating, Shifting and Edge Detection

# %%
img = cv2.imread('oneD.jpg')

#Scaling
# Get number of pixel horizontally and vertically. 
(height, width) = img.shape[:2] 

# Specify the size of image along with interploation methods. 
# cv2.INTER_AREA is used for shrinking, whereas cv2.INTER_CUBIC 
# is used for zooming. 
res = cv2.resize(img, (int(width / 2), int(height / 2)), interpolation = cv2.INTER_CUBIC) 

# Write image back to disk. 
cv2.imwrite('scaling.jpg', res)
# Out:
# True

# %%
# Rotating
# Shape of image in terms of pixels. 
(rows, cols) = img.shape[:2] 

# getRotationMatrix2D creates a matrix needed for transformation. 
# We want matrix for rotation w.r.t center to 45 degree without scaling. 
M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 45, 1) 
res = cv2.warpAffine(img, M, (cols, rows)) 

# Write image back to disk. 
cv2.imwrite('rotate45.jpg', res)
# Out:
# True

# %%
#Shifting
(rows, cols) = img.shape[:2] 
M = np.float32([[1, 0, 100], [0, 1, 50]]) 
  
# warpAffine does appropriate shifting given the 
# translation matrix. 
res = cv2.warpAffine(img, M, (cols, rows)) 

# Write image back to disk. 
cv2.imwrite('shifting.jpg', res)
# Out:
# True

# %%
#Edge Detection
# Canny edge detection. 
edges = cv2.Canny(img, 100, 200) 

# Write image back to disk. 
cv2.imwrite('edge_detect.jpg', edges)
# Out:
# True

# %% [markdown]
# ## 7. Erosion and Delation
#
# #### Erosion:
# - It is useful for removing small white noises.
# - Used to detach two connected objects etc.
#
# #### Dilation:
# - In cases like noise removal, erosion is followed by dilation. Because, erosion removes white noises, but it also shrinks our object. So we dilate it. Since noise is gone, they won’t come back, but our object area increases.
# - It is also useful in joining broken parts of an object.

# %%
img = cv2.imread('edge_detect.jpg', 0)

kernel = np.ones((5,5), np.uint8) 
img_erosion = cv2.erode(img, kernel, iterations=1) 
img_dilation = cv2.dilate(img, kernel, iterations=1)
res = np.concatenate((img_erosion, img_dilation), axis = 1)

cv2.imwrite('erosion_delation.jpg', res)
# Out:
# True

# %% [markdown]
# ## 8. Image Histogram
# using matplotlib and opencv

# %%
#plt_img = plt.imread('oneD.jpg')
cv_img = cv2.imread('oneD.jpg', 0)

#using opencv
#cv2.calcHist(img, channels, mask, histSize, ranges[, hist[, accumulate]])
histr = cv2.calcHist([cv_img],[0],None,[256],[0,256]) 


# show the plotting graph of an image 
plt.plot(histr)
#plt.plot(hist2)
plt.show()

# %%
#Histogram equalization
# creating a Histograms Equalization 
# of a image using cv2.equalizeHist() 
equ = cv2.equalizeHist(cv_img) 
  
# stacking images side-by-side 
res = np.hstack((cv_img, equ)) 

histr = cv2.calcHist([equ],[0],None,[256],[0,256])
plt.plot(histr)
plt.show()

cv2.imwrite('equal_hist.jpg', res)
# Out:
# True

# %% [markdown]
# ## 9. Thresholding
# ### 9.1. Simple Thresholding
# The different Simple Thresholding Techniques are:
#
# - cv2.THRESH_BINARY: If pixel intensity is greater than the set threshold, value set to 255, else set to 0 (black).
# - cv2.THRESH_BINARY_INV: Inverted or Opposite case of cv2.THRESH_BINARY.
# - cv.THRESH_TRUNC: If pixel intensity value is greater than threshold, it is truncated to the threshold. The pixel values are set to be the same as the threshold. All other values remain the same.
# - cv.THRESH_TOZERO: Pixel intensity is set to 0, for all the pixels intensity, less than the threshold value.
# - cv.THRESH_TOZERO_INV: Inverted or Opposite case of cv2.THRESH_TOZERO.

# %%
image1 = cv2.imread('oneD.jpg')  
  
# cv2.cvtColor is applied over the 
# image input with applied parameters 
# to convert the image in grayscale  
img = cv2.cvtColor(image1, cv2.COLOR_BGR2GRAY) 
  
# applying different thresholding  
# techniques on the input image 
# all pixels value above 120 will  
# be set to 255 
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY) 
ret, thresh2 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY_INV) 
ret, thresh3 = cv2.threshold(img, 120, 255, cv2.THRESH_TRUNC) 
ret, thresh4 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO) 
ret, thresh5 = cv2.threshold(img, 120, 255, cv2.THRESH_TOZERO_INV) 
  
x1 = np.concatenate((thresh1, thresh2), axis = 1)
x2 = np.concatenate((thresh3, thresh4), axis = 1)
x3 = np.concatenate((img, thresh5), axis = 1)
res = np.concatenate((x1,x2,x3), axis = 0)

cv2.imwrite('threshold.jpg', res)
# Out:
# True

# %% [markdown]
# ### 9.2. Adaptive Thresholding
#
# cv2.adaptiveThreshold(source, maxVal, adaptiveMethod, thresholdType, blocksize, constant)
#
# Parameters:
# -> source: Input Image array(Single-channel, 8-bit or floating-point)
# -> maxVal: Maximum value that can be assigned to a pixel.
# -> adaptiveMethod: Adaptive method decides how threshold value is calculated.
#
#  cv2.ADAPTIVE_THRESH_MEAN_C: Threshold Value = (Mean of the neighbourhood area values – constant value). In other words, it is the mean of the blockSize×blockSize neighborhood of a point minus constant.
#
# cv2.ADAPTIVE_THRESH_GAUSSIAN_C: Threshold Value = (Gaussian-weighted sum of the neighbourhood values – constant value). In other words, it is a weighted sum of the blockSize×blockSize neighborhood of a point minus constant.
#
# -> thresholdType: The type of thresholding to be applied.
# -> blockSize: Size of a pixel neighborhood that is used to calculate a threshold value.
# -> constant: A constant value that is subtracted from the mean or weighted sum of the neighbourhood pixels.

# %%
img = cv2.imread('oneD.jpg', 0)

# applying different thresholding  
# techniques on the input image 
thresh1 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                                          cv2.THRESH_BINARY, 199, 5) 
  
thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                          cv2.THRESH_BINARY, 199, 5) 

res = np.concatenate((thresh1, thresh2), axis = 1)
cv2.imwrite('adaptive_threshold.jpg', res)
# Out:
# True

# %% [markdown]
# ### 9.3. Otsu thresholding
#
# Trong Ngưỡng Otsu , giá trị của ngưỡng không được chọn nhưng được xác định tự động

# %%
ret, thresh1 = cv2.threshold(img, 120, 255, cv2.THRESH_BINARY + 
                                            cv2.THRESH_OTSU)
                                            
thresh2 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                                          cv2.THRESH_BINARY, 199, 5) 
  
res = np.concatenate((thresh1, thresh2), axis = 1)
cv2.imwrite('otsu_thresholding.jpg', res)
# Out:
# True
